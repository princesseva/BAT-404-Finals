# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
# %matplotlib inline
import csv
import seaborn as sns

# %%
marine_data = pd.read_csv("2019_BeachCleanups.csv")

# %%
marine_data
# Out:
#            Date Details Beach Name/Location       Organization  Items  \
# 0    12/24/2019   Recap    Windy Hill Beach  Individual (1208)    223
# 1    12/11/2019   Recap  North Myrtle Beach  Individual (1109)     13
# 2    11/23/2019   Recap    Sullivans Island               1542    180
# 3    11/21/2019   Recap    Windy Hill Beach  Individual (1208)    212
# 4    11/02/2019   Recap       Isle of Palms               1589    274
# ..          ...     ...                 ...                ...    ...
# 240  01/29/2019   Recap  North Myrtle Beach  Individual (1149)     48
# 241  01/26/2019   Recap         Folly Beach               1979     57
# 242  01/25/2019   Recap         Folly Beach               1979    204
# 243  01/24/2019   Recap         Folly Beach               1979     75
# 244  01/06/2019   Recap  Hilton Head Island  Individual (1118)     20
#
#      Volunteer Hours  Weight
# 0               2.00    5.02
# 1               0.50    0.84
# 2               7.25   13.42
# 3               1.50    5.46
# 4              19.50   13.74
# ..               ...     ...
# 240             0.50    0.55
# 241            35.00    2.87
# 242             2.50    1.51
# 243             0.00    0.33
# 244             1.25    0.13
#
# [245 rows x 7 columns]

# %%
description=marine_data.describe().T
print(description)
# Out:
#                  count        mean         std  min    25%    50%    75%  \
# Items            245.0  113.363265  357.701741  1.0  10.00  27.00  83.00
# Volunteer Hours  245.0    5.169388   15.196826  0.0   0.50   1.50   4.75
# Weight           245.0    4.637224   10.273935  0.0   0.57   1.97   4.82
#
#                      max
# Items            4886.00
# Volunteer Hours   178.00
# Weight            110.23

# %%
##Datavisualization

# %%
description = marine_data.describe()
plt.figure(figsize=(12, 8))

description.loc['mean'].plot(kind='bar')

plt.xlabel('Columns')
plt.ylabel('Mean')
plt.title('Mean Values of Marine data')

plt.show()

# %%
description = marine_data.describe()

# Extract the statistics you want to visualize
statistics = description.loc[['count', 'mean', 'std', 'min', '25%', '50%']]

# Transpose the DataFrame for easier plotting
statistics = statistics.T

# Adjust figure size
plt.figure(figsize=(12, 8))

# Plotting the line graph
statistics.plot(kind='line', marker='o')

# Adding labels and title
plt.xlabel('Columns')
plt.ylabel('Value')
plt.title('Descriptive Statistics')

# Adjust font size
plt.xticks(range(len(statistics.index)), statistics.index, fontsize=8)
plt.xticks(rotation=90)
# Display the plot
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()
